# %%
# Dependencies and Setup
import glob
import pandas as pd

# %%
# glob.glob('data*.csv') - returns List[str]
# pd.read_csv(f) - returns pd.DataFrame()
# for f in glob.glob() - returns a List[DataFrames]
# pd.concat() - returns one pd.DataFrame()
clean_data_usa = pd.concat([pd.read_csv(f) for f in glob.glob('raw_data/usa_data/*.csv')], ignore_index = True)

# %%
clean_data_usa.head()
# Out:
#       id                                               name  host_id  \
# 0  38585                   Charming Victorian twin BR for 2   165529
# 1  80713  Beautiful Downtown Homestead • Monthly • Sky Room  1675743
# 2  80905                        French Industrial Chic Loft   427027
# 3  80965                   Downtown Asheville's Groovy Gem.   438413
# 4  86980       Downtown Urban Homestead • Monthly • Sage Rm  1675743
#
#   host_name neighbourhood_group neighbourhood   latitude  longitude  \
# 0   Evelyne                 NaN         28804  35.651459 -82.627918
# 1    Janell                 NaN         28801  35.586782 -82.549277
# 2   Celeste                 NaN         28801  35.597006 -82.552370
# 3     Kelly                 NaN         28801  35.605291 -82.556274
# 4    Janell                 NaN         28801  35.585129 -82.550871
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Add country column
clean_data_usa['country'] = 'usa'
clean_data_usa.head()
# Out:
#       id                                               name  host_id  \
# 0  38585                   Charming Victorian twin BR for 2   165529
# 1  80713  Beautiful Downtown Homestead • Monthly • Sky Room  1675743
# 2  80905                        French Industrial Chic Loft   427027
# 3  80965                   Downtown Asheville's Groovy Gem.   438413
# 4  86980       Downtown Urban Homestead • Monthly • Sage Rm  1675743
#
#   host_name neighbourhood_group neighbourhood   latitude  longitude  \
# 0   Evelyne                 NaN         28804  35.651459 -82.627918
# 1    Janell                 NaN         28801  35.586782 -82.549277
# 2   Celeste                 NaN         28801  35.597006 -82.552370
# 3     Kelly                 NaN         28801  35.605291 -82.556274
# 4    Janell                 NaN         28801  35.585129 -82.550871
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# Save clean data to csv# Save  # Save c 
clean_data_usa.to_csv('clean_data/clean_data_usa.csv', index = False)
